# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt
import pandas_tasks
plt.plot(df['Name'], df['Score'])
plt.xlabel('Student Name')
plt.ylabel('Score')
plt.title('Student Scores Line Plot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import pandas_tasks
#       3 plt.plot(df['Name'], df['Score'])
#       4 plt.xlabel('Student Name')
#
# ModuleNotFoundError: No module named 'pandas_tasks'

# %%
import matplotlib.pyplot as plt
import pandas_tasks from Notebooks
plt.plot(df['Name'], df['Score'])
plt.xlabel('Student Name')
plt.ylabel('Score')
plt.title('Student Scores Line Plot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import pandas_tasks
#       3 plt.plot(df['Name'], df['Score'])
#       4 plt.xlabel('Student Name')
#
# ModuleNotFoundError: No module named 'pandas_tasks'

# %%
import matplotlib.pyplot as plt
import pandas_tasks.ipynb 
plt.plot(df['Name'], df['Score'])
plt.xlabel('Student Name')
plt.ylabel('Score')
plt.title('Student Scores Line Plot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import pandas_tasks.ipynb
#       3 plt.plot(df['Name'], df['Score'])
#       4 plt.xlabel('Student Name')
#
# ModuleNotFoundError: No module named 'pandas_tasks'

# %%
import matplotlib.pyplot as plt
plt.plot(df['Name'], df['Score'])
plt.xlabel('Student Name') # Label x-axis [cite: 67]
plt.ylabel('Score')        # Label y-axis [cite: 67]
plt.title('Student Scores Line Plot') # Add title [cite: 68]
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(df['Name'], df['Score'])
#       3 plt.xlabel('Student Name') # Label x-axis [cite: 67]
#       4 plt.ylabel('Score')        # Label y-axis [cite: 67]
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [19, 21, 22, 18, 20],
    'Score': [85, 70, 92, 78, 88]
}
df = pd.DataFrame(data)

plt.plot(df['Name'], df['Score'])
plt.xlabel('Student Name')           
plt.ylabel('Score')                 
plt.title('Student Scores Line Plot') 
plt.show()


plt.bar(df['Name'], df['Score'])
plt.xlabel('Student Name')           
plt.ylabel('Score')                 
plt.title('Student Names vs Scores')  
plt.show()
