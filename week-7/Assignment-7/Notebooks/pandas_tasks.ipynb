# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [19, 21, 22, 18, 20],
    'Score': [85, 70, 92, 78, 88]
}
df = pd.DataFrame(data)

# %%
df.head(3)
# Out:
#       Name  Age  Score
# 0    Alice   19     85
# 1      Bob   21     70
# 2  Charlie   22     92

# %%
df.describe()
# Out:
#              Age     Score
# count   5.000000   5.00000
# mean   20.000000  82.60000
# std     1.581139   8.70632
# min    18.000000  70.00000
# 25%    19.000000  78.00000
# 50%    20.000000  85.00000
# 75%    21.000000  88.00000
# max    22.000000  92.00000

# %%
df['Score'].mean()
# Out:
# np.float64(82.6)

# %%
df[df['Age'] > 20]
# Out:
#       Name  Age  Score
# 1      Bob   21     70
# 2  Charlie   22     92

# %%
df[df['Score'] > 80]
# Out:
#       Name  Age  Score
# 0    Alice   19     85
# 2  Charlie   22     92
# 4      Eva   20     88
